# %%
import pandas

# %%
carDataCSV = "/home/ubuntu/.machine-learning/data/car_stuff/craigslistVehiclesFull.csv"

# %%
carsDF = pandas.read_csv(carDataCSV)

# %%
carsDF.head()
# Out:
#                                                  url      city  price    year  \
# 0  https://marshall.craigslist.org/cto/d/2010-dod...  marshall  11900  2010.0
# 1  https://marshall.craigslist.org/cto/d/fleetwoo...  marshall   1515  1999.0
# 2  https://marshall.craigslist.org/cto/d/2008-for...  marshall  17550  2008.0
# 3  https://marshall.craigslist.org/cto/d/ford-tau...  marshall   2800  2004.0
# 4  https://marshall.craigslist.org/cto/d/2001-gra...  marshall    400  2001.0
#
#   manufacturer             make condition    cylinders fuel  odometer  ...  \
# 0        dodge    challenger se      good  6 cylinders  gas   43600.0  ...
# 1          NaN        fleetwood       NaN          NaN  gas       NaN  ...
# 2         ford            f-150       NaN          NaN  gas       NaN  ...
# 3         ford           taurus      good  6 cylinders  gas  168591.0  ...
# 4          NaN  2001 Grand Prix       NaN          NaN  gas  217000.0  ...
#
# ...

# %%
categoricalVariables = ['city', 'manufacturer', 'make', 'cylinders','fuel','paint_color','county_name','state_name']
continuousVariables = ['price','year','odometer','weather']

# %%
# Categorical to dictionary
# datframe to tensor
# ???
# Profit!!

# %%
carsDF[carsDF["year"].isnull()]
# Out:
#                                                        url          city  \
# 1652     https://galveston.craigslist.org/cto/d/2014-ni...     galveston
# 7092     https://saltlakecity.craigslist.org/cto/d/2014...  saltlakecity
# 8555     https://memphis.craigslist.org/ctd/d/2018-toyo...       memphis
# 8641     https://memphis.craigslist.org/ctd/d/2018-toyo...       memphis
# 12831    https://elko.craigslist.org/ctd/d/2018-nissan-...          elko
# ...                                                    ...           ...
# 1720999  https://wyoming.craigslist.org/ctd/d/2011-gmc-...       wyoming
# 1721000  https://wyoming.craigslist.org/cto/d/hyundai-v...       wyoming
# 1721889  https://elko.craigslist.org/ctd/d/2018-ram-250...          elko
# 1722417  https://beaumont.craigslist.org/cto/d/car-disp...      beaumont
# 1722967  https://northmiss.craigslist.org/ctd/d/2018-to...     northmiss
#
#          price  year manufacturer                     make  condition  \
# ...

# %%
from functools import reduce

# %%
categoricalVariableDictionary = {}
for categoricalVariable in categoricalVariables:
    vocab = carsDF[categoricalVariable].str.lower().unique()
    def _toDictionary(dictionary, vocabItem):
        index, vocabToken = vocabItem
        dictionary[vocabToken] = index
        return dictionary
    categoricalVariableDictionary[categoricalVariable] = reduce(_toDictionary, enumerate(vocab), {})

# %%
print(len(carsDF["make"].unique()))
print(len(carsDF["make"].str.lower().unique()))
print(len(carsDF))
# Out:
# 107446
# 97704
# 1723065

# %%
for categoricalVariable in categoricalVariables:
    print(len(carsDF[categoricalVariable].unique()))
# Out:
# 470
# 54
# 107446
# 9
# 6
# 13
# 1835
# 52

# %%
for key, dick in categoricalVariableDictionary.items():
    print(len(dick.items()))
# Out:
# 470
# 54
# 97704
# 9
# 6
# 13
# 1835
# 52

# %%
categoricalVariableDictionary["make"]
# Out:
# {'challenger se': 0,
#  'fleetwood': 1,
#  'f-150': 2,
#  'taurus': 3,
#  '2001 grand prix': 4,
#  'yukon': 5,
#  'patriot high altitude': 6,
#  '3 series': 7,
#  'ebike': 8,
#  'excursion': 9,
#  'express 2500 van': 10,
#  '2500 hd': 11,
#  'sonata': 12,
#  'camaro': 13,
#  'santa fe xl': 14,
#  'cobolt': 15,
#  'cr-v exl': 16,
#  '1500 laramie': 17,
#  'mdx navi': 18,
#  'x1 28i': 19,
#  'rdx premium': 20,
#  'sorento': 21,
#  'rdx elite': 22,
#  'tlx tech': 23,
#  'mdx navi certified': 24,
#  'odyssey touring': 25,
#  'elantra gt': 26,
#  'rdx technology': 27,
#  'touareg': 28,
#  'mdx technology': 29,
#  'odyssey': 30,
#  'model': 31,
#  'murano se': 32,
#  'q5 navigation': 33,
#  'charger sxt': 34,
#  'x5 xdrive35d': 35,
#  'jetta': 36,
#  'q5 3.2': 37,
#  'cla 250': 38,
#  'impreza 2.0i': 39,
#  'csx tech': 40,
#  '300': 41,
#  'escape se': 42,
#  'camry le hybrid': 43,
#  'sport': 44,
#  'challenger sxt': 45,
#  'prius hybrid': 46,
#  '6 mazda6 gt': 47,
#  'rav4': 48,
# ...

# %%
import numpy

# %%
manufacturerToMake = carsDF[["make", "manufacturer"]].replace(numpy.nan, 'N/A', regex=True).groupby("manufacturer")

# %%
for group, dataFrame in manufacturerToMake:
    print(group, len(dataFrame["make"].str.lower().unique()))
# Out:
# N/A 39453
# acura 797
# alfa 29
# alfa-romeo 34
# aston 14
# aston-martin 10
# audi 1212
# bmw 2427
# buick 945
# cadillac 991
# chev 254
# chevrolet 7685
# chevy 2952
# chrysler 1078
# datsun 82
# dodge 3229
# ferrari 64
# fiat 164
# ford 11802
# gmc 3591
# harley 72
# harley-davidson 148
# hennessey 1
# honda 2696
# hyundai 1055
# infiniti 587
# infinity 85
# jaguar 392
# jeep 2200
# kia 878
# land rover 21
# landrover 16
# lexus 854
# lincoln 582
# mazda 1135
# mercedes 1198
# mercedes-benz 2292
# mercedesbenz 3
# mercury 483
# mini 364
# mitsubishi 563
# morgan 5
# nissan 2671
# noble 2
# pontiac 774
# porche 19
# ram 2472
# rover 318
# saturn 443
# subaru 1291
# toyota 4057
# volkswagen 1643
# volvo 872
# vw 541

# %%
carsDF.iloc[manufacturerToMake.groups["toyota"]]["make"].unique()
# Out:
# array(['camry le hybrid', 'prius hybrid', 'rav4', ..., 'pickup 4c4',
#        'corolla cvt', 'tundra double cab... sr5'], dtype=object)
